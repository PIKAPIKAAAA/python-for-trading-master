# %% [markdown]
# <a href="https://colab.research.google.com/github/PIKAPIKAAAA/python-for-trading-master/blob/master/Multiple_assets_portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.67-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.7.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 16.4 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Installing collected packages: lxml, yfinance
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.7.1 yfinance-0.1.67

# %% [markdown]
# Import

# %%
import yfinance as yf
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# Create multiple stock dataframe

# %%
symbols = ['GNRC', 'DXCM', 'AMD', 'NFLX', 'COST','TGT', 'AES', 'MSCI', 'NEM', 'AMT', 'HES']
df = yf.download(symbols, start = '2018-01-01', end = '2021-09-01')
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
df = df['Adj Close']
df
# Out:
#                   AES         AMD  ...        NFLX         TGT
# Date                               ...
# 2018-01-02   9.545206   10.980000  ...  201.070007   61.324654
# 2018-01-03   9.536433   11.550000  ...  205.050003   60.907532
# 2018-01-04   9.501339   12.120000  ...  205.630005   59.710606
# 2018-01-05   9.536433   11.880000  ...  209.990005   60.345345
# 2018-01-08   9.536433   12.280000  ...  212.050003   60.916615
# ...               ...         ...  ...         ...         ...
# 2021-08-25  24.114227  108.300003  ...  547.580017  250.294861
# 2021-08-26  23.726572  107.269997  ...  550.119995  248.112335
# 2021-08-27  24.044649  111.400002  ...  558.919983  248.331573
# 2021-08-30  23.955189  111.320000  ...  566.179993  248.510971
# 2021-08-31  23.726572  110.720001  ...  569.190002  246.139069
#
# [923 rows x 11 columns]

# %% [markdown]
# Plot Stocks

# %%
df[:3]
# Out:
#                  AES    AMD         AMT  ...        NEM        NFLX        TGT
# Date                                     ...
# 2018-01-02  9.545206  10.98  130.570328  ...  34.176994  201.070007  61.324654
# 2018-01-03  9.536433  11.55  131.079163  ...  33.890396  205.050003  60.907532
# 2018-01-04  9.501339  12.12  129.164062  ...  34.266556  205.630005  59.710606
#
# [3 rows x 11 columns]

# %%
(df / df.iloc[0] * 100).plot(figsize=(16,9))

# %%
returns = np.log(df / df.shift(1))
mean_return = returns.mean() * 252

mean_return
# Out:
# AES     0.248872
# AMD     0.631621
# AMT     0.217512
# COST    0.257942
# DXCM    0.604448
# GNRC    0.603505
# HES     0.116467
# MSCI    0.448482
# NEM     0.139238
# NFLX    0.284405
# TGT     0.379835
# dtype: float64

# %%
returns.cov() * 252
# Out:
#            AES       AMD       AMT  ...       NEM      NFLX       TGT
# AES   0.144203  0.055266  0.042063  ...  0.021986  0.032133  0.038466
# AMD   0.055266  0.312655  0.041158  ...  0.035442  0.102382  0.057842
# AMT   0.042063  0.041158  0.080622  ...  0.020820  0.030778  0.028514
# COST  0.025596  0.047267  0.030208  ...  0.013200  0.038660  0.033987
# DXCM  0.043813  0.093411  0.036804  ...  0.021077  0.064031  0.030436
# GNRC  0.065557  0.086732  0.042595  ...  0.025463  0.051556  0.041750
# HES   0.093453  0.083106  0.037882  ...  0.029886  0.043042  0.040944
# MSCI  0.062098  0.094960  0.047314  ...  0.026417  0.063980  0.034737
# NEM   0.021986  0.035442  0.020820  ...  0.107179  0.014270  0.009445
# NFLX  0.032133  0.102382  0.030778  ...  0.014270  0.169375  0.031428
# TGT   0.038466  0.057842  0.028514  ...  0.009445  0.031428  0.097915
#
# [11 rows x 11 columns]

# %% [markdown]
# Correlation

# %%
corr_df = returns.corr()

# %%
corr_df
# Out:
#            AES       AMD       AMT  ...       NEM      NFLX       TGT
# AES   1.000000  0.260278  0.390112  ...  0.176848  0.205607  0.323713
# AMD   0.260278  1.000000  0.259238  ...  0.193612  0.444906  0.330589
# AMT   0.390112  0.259238  1.000000  ...  0.223973  0.263381  0.320931
# COST  0.305519  0.383158  0.482229  ...  0.182756  0.425784  0.492317
# DXCM  0.237933  0.344512  0.267300  ...  0.132768  0.320851  0.200589
# GNRC  0.433836  0.389800  0.376990  ...  0.195455  0.314808  0.335296
# HES   0.453100  0.273646  0.245637  ...  0.168074  0.192557  0.240907
# MSCI  0.468507  0.486557  0.477405  ...  0.231180  0.445393  0.318046
# NEM   0.176848  0.193612  0.223973  ...  1.000000  0.105913  0.092195
# NFLX  0.205607  0.444906  0.263381  ...  0.105913  1.000000  0.244043
# TGT   0.323713  0.330589  0.320931  ...  0.092195  0.244043  1.000000
#
# [11 rows x 11 columns]

# %% [markdown]
# Plot correlation matrix

# %%
plt.figure(figsize=(13,8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()

# %% [markdown]
# Generate random weights (sum=1)

# %%
weights = np.random.random(len(symbols))
weights = weights / np.sum(weights)
print(weights)
print('')
print(sum(weights))
# Out:
# [0.0691272  0.10064338 0.01579506 0.11470562 0.04245915 0.09984925
#  0.04732238 0.12815151 0.16495977 0.14417783 0.07280886]
#
# 0.9999999999999998

# %% [markdown]
# Calculate return for portfolio

# %%
np.sum(weights * returns.mean()) * 252
# Out:
# 0.35433329379679823

# %%
np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights)))
# Out:
# 0.2359321620179056

# %% [markdown]
# analyzing returns and risks of 10k combinations

# %%
p_ret = []
p_vol = []
p_SR = []
p_wt = []

for x in range(10000):
  
  p_weights = np.random.random(len(symbols))
  p_weights =  p_weights / np.sum(p_weights)
  
  ret_1 = np.sum(p_weights * returns.mean()) * 252
  p_ret.append(ret_1)

  vol_1 = np.sqrt(np.dot(p_weights.T, np.dot(returns.cov() * 252, p_weights)))
  p_vol.append(vol_1)

  SR_1 = ret_1 / vol_1
  p_SR.append(SR_1)
  
  p_wt.append(p_weights)

p_ret = np.array(p_ret)
p_vol = np.array(p_vol)
p_SR = np.array(p_SR)
p_wt= np.array(p_wt)

# %%
len(p_ret)
# Out:
# 10000

# %% [markdown]
# PLOT THE EFFICENT FRONTIER

# %%
ports = pd.DataFrame({'Return': p_ret, 'Volatility': p_vol})

ports.plot(x='Volatility', y='Return', kind='scatter', figsize=(13,8))

# %% [markdown]
# find max sharp ratio

# %%
SR_idx = np.argmax(p_SR)

i = 0
while i < len(symbols):
  print('Stock : %s : %2.2f' % (symbols[i], (p_wt[SR_idx][i] * 100)))
  i += 1


print('\nReturn :', p_ret[SR_idx])

print('Volatility :', p_vol[SR_idx])

print('Sharp Ratio :', p_SR[SR_idx])
# Out:
# Stock : GNRC : 3.92
# Stock : DXCM : 5.00
# Stock : AMD : 3.08
# Stock : NFLX : 15.81
# Stock : COST : 19.07
# Stock : TGT : 19.25
# Stock : AES : 2.20
# Stock : MSCI : 12.43
# Stock : NEM : 3.27
# Stock : AMT : 0.33
# Stock : HES : 15.64
#
# Return : 0.44346973143688223
# Volatility : 0.24731491874904565
# Sharp Ratio : 1.7931378085884013
